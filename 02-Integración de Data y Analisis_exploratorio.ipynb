# %% [markdown]
# # 02-Análisis Exploratorio y Generación de Hipótesis
#
# En este notebook exploraremos la data obtenida del análisis de churn en el notebook anterior. Posteriormente, se analizará el comportamiento de las variables obtenidas y se procederá a formular algunas hipótesis relacionadas con el comportamiento de la variable de interés.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from utils import *
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
# Out:
# C:\Users\jhonp\miniconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
##leer data churn y fuentes exploradas anteriormente
churn_data=pd.read_csv("churn_data.csv",sep=";")

# %% [markdown]
# ### Exploración univariada de las variables
#
# Desde esta vista podemos ver que las variables MdeloVehiculo__c y MarcaVehiculo__c no tienen valores que permitan diferenciar algún comportamiento de la variable de interés, por tanto no serán incluidas.

# %%
for col in churn_data.drop(columns=["Asegurado__c","PuntoVenta__c","anios_ultimo_siniestro","total_pagado_smmlv","NumeroPoliza__c","FechaInicioVigencia__ctrim","vigencia_dias","end_vig"]).columns:
    print(churn_data.groupby(col).agg({'churn':'count'}))
# Out:
#                         churn
# CodigoTipoAsegurado__c
# 1                       63481
# 2                        1352
# 3                         805
# 4                        1552
#              churn
# Producto__c
# 1             1357
# 3                4
# 4             1182
# 5               64
# 6               43
# 7              581
# 8               16
# 9               25
# 10              29
# 11              20
# 12              65
# 13             119
# 14             190
# 16               6
# 17            1576
# 18               6
# 19              72
# 20               6
# 21             513
# 22              13
# 24              20
# 26              26
# 27               3
# 31               5
# 33              82
# 34              29
# 35             493
# 37              47
# 39               1
# 51              16
# 52              39
# 59               2
# 66             139
# 67              14
# 69               4
# 70             194
# 78              12
# 88              18
# 89              25
# 93             359
# 95             963
# 96              64
# 99             974
# 105            142
# 106              3
# 107              1
# 99999        57628
#                                                churn
# tipo_poliza_name
# colectiva                                        158
# de daños                                         889
# de daños tradicional                            1138
# de deudores hipotecarios                         743
# de disposiciones legales                          25
# flotante                                         469
# global sector privado                            412
# individual                                      5165
# normal                                           256
# otras                                           2555
# responsabilidad civil                           2642
# s.o.a.t                                        52242
# todo riesgo de obras civiles daños materiales    429
# unica a favor de entidades estatales              67
#                  churn
# tipo_prod_desc
# au ded unic liv    493
# au excepciones     505
# convenios         1576
# disp legales        25
# otras            64591
#                   churn
# ClaseVehiculo__c
# 1                 46755
# 2                  1426
# 3                   527
# 4                   105
# 5                  2934
# 6                   196
# 7                   214
# 8                    24
# 9                    61
# 99999             14948
#                   churn
# MarcaVehiculo__c
# 97.0              52242
#                   churn
# MdeloVehiculo__c
# 999.0             52242
#                  churn
# TipoVehiculo__c
# 0                52242
# 99999            14948
#                 churn
# RamoTecnico__c
# 1                 728
# 2                  93
# 3                1602
# 4                 790
# 5                 145
# 6                  28
# 7                5323
# 8               52242
# 11               1595
# 13               3738
# 14                  2
# 15                 18
# 17                107
# 18                 16
# 19                130
# 23                  3
# 29                  1
# 81                212
# 83                288
# 84                129
#                churn
# Tipo_poliza_c
# 1              62245
# 2                279
# 3                225
# 4               3107
# 5                 17
# 6                  1
# 7                  1
# 8               1287
# 11                26
# 14                 2
#        churn
# churn
# False  12463
# True   54727
#              churn
# n_prod_prev
# 1.0           1580
# 2.0             94
# 3.0           1038
# 4.0             10
# 8.0            947
#                   churn
# total_siniestros
# 1.0                 896
# 2.0                 273
# 3.0                 266
# 4.0                 225
# 5.0                  98
# 6.0                  40
# 7.0                  81
# 8.0                 100
# 9.0                  33
# 10.0                 52
# 11.0                  6
# 12.0                 12
# 13.0                  2
# 14.0                 18
# 15.0                114
# 16.0                481
# 19.0                106
# 20.0                  2
# 21.0                  3
# 22.0                 22
# 28.0                 82
# 32.0                  2
# 36.0                  2
# 37.0                569
# 38.0                948
# 45.0                  6
# 51.0                  1
# 52.0                  9
# 80.0                  5
# 90.0                  2
# 150.0               974
# 940.0                 3
